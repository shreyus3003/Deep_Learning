# %% [markdown]
# #            Mnist using numpy

# %%
import sys
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
import math
from keras.preprocessing.image import ImageDataGenerator
from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import itertools
np.random.seed(1)

# %% [markdown]
# ###1.1 Data Loading: (method : data_prep())
#   The mnist dataset is loaded from the keras datasets, the train and test data are seperated. One hot encoding is done fo the train and test labels in the same function.

# %%
def data_prep(x_train, y_train, x_test, y_test):
  #images, labels = (x_train[0:1000].reshape(1000, 28*28)/ 255, y_train[0:1000])
  images, labels = (x_train.reshape(len(x_train), 28*28)/ 255, y_train)
  one_hot_labels = np.zeros((len(labels), 10))
  for i, l in enumerate(labels):
    one_hot_labels[i][l] = 1
  labels = one_hot_labels
  test_images = x_test.reshape(len(x_test), 28*28)/255
  test_labels = np.zeros((len(y_test), 10))
  for i, l in enumerate(y_test):
    test_labels[i][l] = 1
  return (images, labels, test_images, test_labels)

# %% [markdown]
# ###1.2 Activation functions:
#   Activation functions RELU, RELU2Deriv and softmax activations functions are defined.

# %%
relu = lambda x: (x>=0) * x
relu2derive = lambda x: x>=0
def softmax(x):
  temp = np.exp(x)
  return temp/np.sum(temp, axis=1, keepdims=True)

# %% [markdown]
# ###1.3 Preview of images:

# %%
plt.figure(figsize=(15,4.5))
for i in range(30):  
    plt.subplot(3, 10, i+1)
    plt.imshow(images[i].reshape((28,28)),cmap=plt.cm.binary)
    plt.axis('off')
plt.subplots_adjust(wspace=-0.1, hspace=-0.1)
plt.show()

# %% [markdown]
# #2. Class Simple Neural Network(SNN):
#   The class takes the basic parameters like images, alpha value, number of epochs, labels, and boolean dropout
# ###2.1 Weights Initialization:
#   Intial weights for each layer is defined, random values are choosen to initialize the weights.
# ###2.2 Activation Function:
#   Relu and softmax activation functions are called for each layer respectively and dropout is also applied in this function
#
# ###2.3 Forward propogation function:
#   activation for each layer is calculated.
# ###2.4 Backpropogation function:
#   The gradient is calculated for each layer.
# ###2.5 Weight updation:
#   The new weights for each layer is calculated with respect to the gradient calculated earlier. Different alpha value is used in each epoc for weights calculations.
# ###2.6 Image augmentation:
#   The image augmentation is done by rotating, zooming, shifting the width and shifting the height.
# ###2.7 Train Images:
#   10 iterations are implemented to train the model with a total images of 60k images with a batch size of 130 in each batch. The resulting weights used for the validation of test images.
# ###2.8 Confusion Matrix Plot:
#   Confusion matrix is plotted using the predicted values from the model.
# ###2.8 Predict model:
#   The resulting weights are applied on the layers resulting in a test accuracy 81%

# %%
#Class Simple Neural Network(SNN):
class SNNetwork:
  def __init__(self, images, batch_size, alpha, iterations, layers, labels,drop_out):
    self.images = images
    self.batch_size = batch_size
    self.alpha = alpha
    self.iterations = iterations
    self.layers = layers
    self.labels = labels
    self.drop_out = drop_out

#Weights Initialization:    
  def ini_weights(self):
    weights = [None] * (len(self.layers)-1)
    a = [0.204, 0.215, 0.22, 0.328]
    #a = [0.228, 0.210, 0.205, 0.328]
    for i in range(len(self.layers)-1):
      weights[i] = a[i] * np.random.random((self.layers[i], self.layers[i+1])) -0.1
    return weights

#Activation Function:
  def activation(self,l, w,d):
    layer = np.dot(l,w)
    relu(layer)
    if(self.drop_out == True and d==0):
      dropout_mask = np.random.randint(2, size = layer.shape)
      layer *= dropout_mask * 2
    return layer
    
#Forward propogation function: 
  def forward_prop(self, layer_in, weights):
    ec_layer = []
    next_layer = [None] * (len(self.layers)-2)
    
    ec_layer.append(layer_in)
    for i in range(len(self.layers)-2):
      d = i
      next_layer[i] = self.activation(ec_layer[i], weights[i], d)
      ec_layer.append(next_layer[i])
    layer_out = softmax(np.dot(ec_layer[-1], weights[-1]))
    ec_layer.append(layer_out)
    return ec_layer

#Backpropogation function:
  def back_prop(self, each_layer, batch_start, batch_end, weights):
    grad = []
    delta = [None] * (len(self.layers)-2)
    op_delta = (self.labels[batch_start:batch_end] - each_layer[-1])/self.batch_size
    temp = op_delta
    for i in range(1,len(each_layer)-1):
      delta[-i] = op_delta.dot(weights[-i].T) * relu2derive(each_layer[-i-1])
      op_delta = delta[-i]
    
    for j in range(len(delta)):
      grad.append(delta[j])
    grad.append(temp)
    return grad
  
#Weight updation:
  def weights_up(self, gradients, each_layer,weights, alpha):
    for i in range(len(weights)):
      weights[i] = weights[i] + self.alpha*np.dot(each_layer[i].T, gradients[i])
    return weights

#Image augmentation:
  def imageAug(self, images):
  
    images = images.reshape(-1,28,28,1)
    datagen = ImageDataGenerator(
              rotation_range=10,  
              zoom_range = 0.50,  
              width_shift_range=0.1, 
              height_shift_range=0.1)


    datagen.fit(images)
    batches = datagen.flow(images, batch_size = len(images))
    x_batch = next(batches)
    x_batch = x_batch.reshape(len(images), 28*28)
    return x_batch
  
#Confusion Matrix plot:
  def plot_confusion_matrix(self, cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

 #Train Images:     
  def train_net(self,weights):
    alpha = self.alpha
    train_loss, train_acc = (0.0, 0)
    aug_images = self.images[0:1000]
    for i in range(int(len(aug_images)/self.batch_size)):
      batch_start, batch_end = (i*self.batch_size, (i+1)*self.batch_size)
      layer_in = aug_images[batch_start:batch_end]
      each_layer = self.forward_prop(layer_in, weights)
      train_loss += np.sum((each_layer[-1] - self.labels[batch_start:batch_end]) **2)
      for k in range(self.batch_size):
        train_acc += int(np.argmax(each_layer[-1][k:k+1]) == np.argmax(self.labels[batch_start+k:batch_start+k+1]))

        gradients = self.back_prop(each_layer, batch_start, batch_end, weights)
        weights = self.weights_up(gradients,each_layer, weights, alpha)
    
    alpha = alpha + 0.000005
    
    # if(acc>temp):
    #   temp = acc
    #   g_weights = weights
    return (train_loss, train_acc, weights)

#Predict model:
  def nn_fit(self,test_images, test_labels):
    images = self.images[0:1000]
    weights = self.ini_weights()
    tr_loss = []
    tes_loss = []
    for j in range(self.iterations):
      y_pred = []
      test_error, test_cnt = (0.0, 0)
      train_loss,train_acc,weights = self.train_net(weights)

      for i in range(len(test_images)):
        layer_in = test_images[i:i+1]
        each_layer = self.forward_prop(layer_in, weights)
        y = each_layer[-1]
        y_pred.append(y)

        test_error += np.sum((test_labels[i:i+1] - each_layer[-1]) **2)
        test_cnt += int(np.argmax(each_layer[-1]) == np.argmax(test_labels[i:i+1]))

      #tr = train_acc/float(len(images))
      #ts = test_cnt/float(len(test_images))
      tr_loss.append(train_loss/float(len(images)))
      tes_loss.append(test_error/float(len(test_images)))  
      print("Epoch",str(j)," train_loss:" + str(train_loss/float(len(images)))[0:5], \
            "Train accuracy:",format((train_acc/float(len(images))),'.4f'),\
            "Validation_loss:" + str(test_error/float(len(test_images)))[0:5], \
            "Val accuracy:",format((test_cnt/float(len(test_images))), '.4f'))
    
    y_pred = np.array(y_pred)
    y_pred = y_pred.reshape(10000,10)
    return y_pred, tr_loss, tes_loss

#Plot the graph
  def plot_validation(self, tr_loss, tes_loss):
    epoch_count = range(1, len(tr_loss) + 1)

    # Visualize loss history
    plt.plot(epoch_count, tr_loss, 'r--')
    plt.plot(epoch_count, tes_loss, 'b-')
    plt.legend(['Training Loss', 'Test Loss'])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.show()

#plot the missed predictions
  def display_errors(self,errors_index,img_errors,pred_errors, obs_errors):
    n = 0
    nrows = 2
    ncols = 3
    fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[error]).reshape((28,28)))
            ax[row,col].set_title("\nPredicted label :{}\nTrue label :{}".format(pred_errors[error],obs_errors[error]))
            n += 1
    plt.show()

# %% [markdown]
# ##3. Main
# #3.1 Initialize Model:
#   The model is initialized with 3 hidden layers and defining the neurons in each layer.

# %%
image_pixel, num_labels = (784,10)
hidden_layers = [256,192]
layer_size = [image_pixel]
for i in range(len(hidden_layers)):
  layer_size.append(hidden_layers[i])
layer_size.append(num_labels)

(x_train, y_train) , (x_test, y_test) = mnist.load_data()
images, labels, test_images, test_labels = data_prep(x_train, y_train, x_test, y_test)
np.random.seed(1)

#Initialize Model:
model = SNNetwork(images=images, batch_size=100, alpha = 0.000224, iterations=100, layers=layer_size, labels=labels, drop_out=True )
y_pred, tr_loss, tes_loss = model.nn_fit(test_images, test_labels)

Y_pred_classes = np.argmax(y_pred,axis =1) 
Y_true = np.argmax(test_labels,axis = 1)
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
model.plot_confusion_matrix(confusion_mtx, classes = range(10))
model.plot_validation(tr_loss, tes_loss)
# Out:
# Epoch 0  train_loss:0.914 Train accuracy: 0.1440 Validation_loss:0.870 Val accuracy: 0.2147
# Epoch 1  train_loss:0.828 Train accuracy: 0.3050 Validation_loss:0.804 Val accuracy: 0.3493
# Epoch 2  train_loss:0.749 Train accuracy: 0.4360 Validation_loss:0.736 Val accuracy: 0.4597
# Epoch 3  train_loss:0.686 Train accuracy: 0.5030 Validation_loss:0.679 Val accuracy: 0.5287
# Epoch 4  train_loss:0.619 Train accuracy: 0.6050 Validation_loss:0.629 Val accuracy: 0.5736
# Epoch 5  train_loss:0.573 Train accuracy: 0.6410 Validation_loss:0.586 Val accuracy: 0.6043
# Epoch 6  train_loss:0.524 Train accuracy: 0.6860 Validation_loss:0.555 Val accuracy: 0.6253
# Epoch 7  train_loss:0.488 Train accuracy: 0.6850 Validation_loss:0.518 Val accuracy: 0.6561
# Epoch 8  train_loss:0.465 Train accuracy: 0.7030 Validation_loss:0.502 Val accuracy: 0.6650
# Epoch 9  train_loss:0.433 Train accuracy: 0.7220 Validation_loss:0.481 Val accuracy: 0.6693
# Epoch 10  train_loss:0.408 Train accuracy: 0.7460 Validation_loss:0.459 Val accuracy: 0.6863
# Epoch 11  train_loss:0.396 Train accuracy: 0.7480 Validation_loss:0.443 Val accuracy: 0.6947
# Epoch 12  train_loss:0.381 Train accuracy: 0.7530 Validation_loss:0.432 Val accuracy: 0.7046
# Epoch 13  train_loss:0.367 Train accuracy: 0.7550 Validation_loss:0.416 Val accuracy: 0.7140
# Epoch 14  train_loss:0.352 Train accuracy: 0.7710 Validation_loss:0.407 Val accuracy: 0.7160
# Epoch 15  train_loss:0.344 Train accuracy: 0.7790 Validation_loss:0.397 Val accuracy: 0.7245
# Epoch 16  train_loss:0.330 Train accuracy: 0.7910 Validation_loss:0.394 Val accuracy: 0.7233
# Epoch 17  train_loss:0.320 Train accuracy: 0.7870 Validation_loss:0.384 Val accuracy: 0.7289
# Epoch 18  train_loss:0.312 Train accuracy: 0.7900 Validation_loss:0.383 Val accuracy: 0.7321
# Epoch 19  train_loss:0.308 Train accuracy: 0.8000 Validation_loss:0.364 Val accuracy: 0.7428
# Epoch 20  train_loss:0.295 Train accuracy: 0.8120 Validation_loss:0.364 Val accuracy: 0.7419
# Epoch 21  train_loss:0.286 Train accuracy: 0.8180 Validation_loss:0.356 Val accuracy: 0.7552
# Epoch 22  train_loss:0.301 Train accuracy: 0.7950 Validation_loss:0.352 Val accuracy: 0.7540
# Epoch 23  train_loss:0.275 Train accuracy: 0.8150 Validation_loss:0.353 Val accuracy: 0.7500
# Epoch 24  train_loss:0.269 Train accuracy: 0.8100 Validation_loss:0.344 Val accuracy: 0.7603
# Epoch 25  train_loss:0.274 Train accuracy: 0.8130 Validation_loss:0.345 Val accuracy: 0.7602
# Epoch 26  train_loss:0.264 Train accuracy: 0.8310 Validation_loss:0.339 Val accuracy: 0.7658
# Epoch 27  train_loss:0.256 Train accuracy: 0.8380 Validation_loss:0.335 Val accuracy: 0.7639
# Epoch 28  train_loss:0.257 Train accuracy: 0.8230 Validation_loss:0.334 Val accuracy: 0.7677
# Epoch 29  train_loss:0.260 Train accuracy: 0.8220 Validation_loss:0.335 Val accuracy: 0.7639
# Epoch 30  train_loss:0.252 Train accuracy: 0.8330 Validation_loss:0.326 Val accuracy: 0.7753
# Epoch 31  train_loss:0.237 Train accuracy: 0.8490 Validation_loss:0.327 Val accuracy: 0.7715
# Epoch 32  train_loss:0.251 Train accuracy: 0.8310 Validation_loss:0.326 Val accuracy: 0.7680
# Epoch 33  train_loss:0.243 Train accuracy: 0.8320 Validation_loss:0.321 Val accuracy: 0.7765
# Epoch 34  train_loss:0.227 Train accuracy: 0.8510 Validation_loss:0.312 Val accuracy: 0.7822
# Epoch 35  train_loss:0.237 Train accuracy: 0.8340 Validation_loss:0.316 Val accuracy: 0.7835
# Epoch 36  train_loss:0.237 Train accuracy: 0.8380 Validation_loss:0.316 Val accuracy: 0.7809
# Epoch 37  train_loss:0.227 Train accuracy: 0.8450 Validation_loss:0.320 Val accuracy: 0.7775
# Epoch 38  train_loss:0.215 Train accuracy: 0.8590 Validation_loss:0.314 Val accuracy: 0.7791
# Epoch 39  train_loss:0.218 Train accuracy: 0.8540 Validation_loss:0.312 Val accuracy: 0.7861
# Epoch 40  train_loss:0.225 Train accuracy: 0.8540 Validation_loss:0.310 Val accuracy: 0.7823
# Epoch 41  train_loss:0.217 Train accuracy: 0.8500 Validation_loss:0.306 Val accuracy: 0.7864
# Epoch 42  train_loss:0.223 Train accuracy: 0.8540 Validation_loss:0.307 Val accuracy: 0.7831
# Epoch 43  train_loss:0.226 Train accuracy: 0.8450 Validation_loss:0.311 Val accuracy: 0.7810
# Epoch 44  train_loss:0.205 Train accuracy: 0.8570 Validation_loss:0.299 Val accuracy: 0.7905
# Epoch 45  train_loss:0.217 Train accuracy: 0.8520 Validation_loss:0.300 Val accuracy: 0.7921
# Epoch 46  train_loss:0.213 Train accuracy: 0.8460 Validation_loss:0.297 Val accuracy: 0.7938
# Epoch 47  train_loss:0.203 Train accuracy: 0.8650 Validation_loss:0.299 Val accuracy: 0.7919
# Epoch 48  train_loss:0.204 Train accuracy: 0.8670 Validation_loss:0.303 Val accuracy: 0.7919
# Epoch 49  train_loss:0.211 Train accuracy: 0.8460 Validation_loss:0.296 Val accuracy: 0.7906
# Epoch 50  train_loss:0.198 Train accuracy: 0.8730 Validation_loss:0.299 Val accuracy: 0.7934
# Epoch 51  train_loss:0.203 Train accuracy: 0.8640 Validation_loss:0.299 Val accuracy: 0.7921
# Epoch 52  train_loss:0.198 Train accuracy: 0.8630 Validation_loss:0.292 Val accuracy: 0.7964
# Epoch 53  train_loss:0.189 Train accuracy: 0.8770 Validation_loss:0.295 Val accuracy: 0.7949
# Epoch 54  train_loss:0.201 Train accuracy: 0.8640 Validation_loss:0.286 Val accuracy: 0.8020
# Epoch 55  train_loss:0.194 Train accuracy: 0.8620 Validation_loss:0.297 Val accuracy: 0.7901
# Epoch 56  train_loss:0.210 Train accuracy: 0.8560 Validation_loss:0.285 Val accuracy: 0.8038
# Epoch 57  train_loss:0.201 Train accuracy: 0.8610 Validation_loss:0.285 Val accuracy: 0.8024
# Epoch 58  train_loss:0.193 Train accuracy: 0.8760 Validation_loss:0.284 Val accuracy: 0.8018
# Epoch 59  train_loss:0.203 Train accuracy: 0.8710 Validation_loss:0.287 Val accuracy: 0.8005
# Epoch 60  train_loss:0.185 Train accuracy: 0.8800 Validation_loss:0.286 Val accuracy: 0.8014
# Epoch 61  train_loss:0.180 Train accuracy: 0.8800 Validation_loss:0.285 Val accuracy: 0.8019
# Epoch 62  train_loss:0.191 Train accuracy: 0.8650 Validation_loss:0.291 Val accuracy: 0.8012
# Epoch 63  train_loss:0.185 Train accuracy: 0.8850 Validation_loss:0.285 Val accuracy: 0.8032
# Epoch 64  train_loss:0.184 Train accuracy: 0.8800 Validation_loss:0.288 Val accuracy: 0.8015
# Epoch 65  train_loss:0.175 Train accuracy: 0.8860 Validation_loss:0.288 Val accuracy: 0.8026
# Epoch 66  train_loss:0.184 Train accuracy: 0.8760 Validation_loss:0.279 Val accuracy: 0.8066
# Epoch 67  train_loss:0.180 Train accuracy: 0.8780 Validation_loss:0.283 Val accuracy: 0.8032
# Epoch 68  train_loss:0.178 Train accuracy: 0.8780 Validation_loss:0.279 Val accuracy: 0.8083
# Epoch 69  train_loss:0.178 Train accuracy: 0.8780 Validation_loss:0.284 Val accuracy: 0.8006
# Epoch 70  train_loss:0.184 Train accuracy: 0.8710 Validation_loss:0.283 Val accuracy: 0.8068
# Epoch 71  train_loss:0.174 Train accuracy: 0.8800 Validation_loss:0.285 Val accuracy: 0.8017
# Epoch 72  train_loss:0.183 Train accuracy: 0.8690 Validation_loss:0.285 Val accuracy: 0.8025
# Epoch 73  train_loss:0.159 Train accuracy: 0.8980 Validation_loss:0.285 Val accuracy: 0.8026
# Epoch 74  train_loss:0.163 Train accuracy: 0.8950 Validation_loss:0.285 Val accuracy: 0.8033
# Epoch 75  train_loss:0.173 Train accuracy: 0.8800 Validation_loss:0.280 Val accuracy: 0.8084
# Epoch 76  train_loss:0.168 Train accuracy: 0.8890 Validation_loss:0.276 Val accuracy: 0.8103
# Epoch 77  train_loss:0.183 Train accuracy: 0.8660 Validation_loss:0.279 Val accuracy: 0.8085
# Epoch 78  train_loss:0.180 Train accuracy: 0.8790 Validation_loss:0.283 Val accuracy: 0.8060
# Epoch 79  train_loss:0.170 Train accuracy: 0.8850 Validation_loss:0.275 Val accuracy: 0.8083
# Epoch 80  train_loss:0.161 Train accuracy: 0.8960 Validation_loss:0.277 Val accuracy: 0.8087
# Epoch 81  train_loss:0.160 Train accuracy: 0.8890 Validation_loss:0.275 Val accuracy: 0.8120
# Epoch 82  train_loss:0.158 Train accuracy: 0.8940 Validation_loss:0.280 Val accuracy: 0.8060
# Epoch 83  train_loss:0.169 Train accuracy: 0.8850 Validation_loss:0.279 Val accuracy: 0.8103
# Epoch 84  train_loss:0.165 Train accuracy: 0.8910 Validation_loss:0.275 Val accuracy: 0.8078
# Epoch 85  train_loss:0.158 Train accuracy: 0.8970 Validation_loss:0.286 Val accuracy: 0.8044
# Epoch 86  train_loss:0.165 Train accuracy: 0.8820 Validation_loss:0.283 Val accuracy: 0.8068
# Epoch 87  train_loss:0.156 Train accuracy: 0.8950 Validation_loss:0.276 Val accuracy: 0.8112
# Epoch 88  train_loss:0.156 Train accuracy: 0.8800 Validation_loss:0.277 Val accuracy: 0.8103
# Epoch 89  train_loss:0.154 Train accuracy: 0.8940 Validation_loss:0.273 Val accuracy: 0.8143
# Epoch 90  train_loss:0.144 Train accuracy: 0.9020 Validation_loss:0.272 Val accuracy: 0.8112
# Epoch 91  train_loss:0.155 Train accuracy: 0.8940 Validation_loss:0.276 Val accuracy: 0.8125
# Epoch 92  train_loss:0.162 Train accuracy: 0.8900 Validation_loss:0.268 Val accuracy: 0.8164
# Epoch 93  train_loss:0.149 Train accuracy: 0.9060 Validation_loss:0.272 Val accuracy: 0.8178
# Epoch 94  train_loss:0.145 Train accuracy: 0.9020 Validation_loss:0.272 Val accuracy: 0.8144
# Epoch 95  train_loss:0.148 Train accuracy: 0.8980 Validation_loss:0.273 Val accuracy: 0.8138
# Epoch 96  train_loss:0.150 Train accuracy: 0.8990 Validation_loss:0.282 Val accuracy: 0.8044
# Epoch 97  train_loss:0.152 Train accuracy: 0.9000 Validation_loss:0.271 Val accuracy: 0.8149
# Epoch 98  train_loss:0.150 Train accuracy: 0.8970 Validation_loss:0.282 Val accuracy: 0.8086
# Epoch 99  train_loss:0.153 Train accuracy: 0.9010 Validation_loss:0.278 Val accuracy: 0.8095

# %%
errors = (Y_pred_classes - Y_true != 0)
Y_pred_classes_errors = Y_pred_classes[errors]
Y_pred_errors = y_pred[errors]
Y_true_errors = Y_true[errors]
X_val_errors = test_images[errors]

Y_pred_errors_prob = np.max(Y_pred_errors,axis = 1)
true_prob_errors = np.diagonal(np.take(Y_pred_errors, Y_true_errors, axis=1))
delta_pred_true_errors = Y_pred_errors_prob - true_prob_errors
sorted_dela_errors = np.argsort(delta_pred_true_errors)
most_important_errors = sorted_dela_errors[-6:]
model.display_errors(most_important_errors, X_val_errors, Y_pred_classes_errors, Y_true_errors)
